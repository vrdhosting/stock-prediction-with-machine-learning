# %% [markdown]
# # Initial Steps Of installation:
# 1. Install ipykernel : pip install ipykernel
# 2. create a file with ipynb extension for juypter notebook

# %% [markdown]
# # 1. GoogleAI API
# requires packages langchain_google_genai,ipykernel

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os
import json

#load Model
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0.7,
    google_api_key="AIzaSyCUtpO8U3teVJ03i3j1xCPNYSDyhYqqkJc"
)

# User input

user_query = input("Enter your Query: ")
print("The Query is:", user_query)

# Generate response
response = model.invoke(user_query)

output = {
    "query": user_query,
    "response": {
        "content": response.content,
    }
}

json_output = json.dumps(output, indent=2)
json_output = json_output.replace('\\n', '\n')
print(json_output)
# Out:
# The Query is: distance of earth from sun?
# {
#   "query": "distance of earth from sun?",
#   "response": {
#     "content": "The distance of Earth from the Sun is not constant because Earth's orbit is elliptical, not a perfect circle. However, here are the key figures:
#
# 1.  **Average Distance:**
#     *   Approximately **150 million kilometers** (km)
#     *   Approximately **93 million miles**
#
# 2.  **Astronomical Unit (AU):**
#     *   This average distance is defined as **1 Astronomical Unit (AU)**. This unit is very useful for measuring distances within our solar system.
#
# 3.  **Variations:**
#     *   **Perihelion (closest point):** Around early January, Earth is about **147 million km** (91 million miles) from the Sun.
#     *   **Aphelion (farthest point):** Around early July, Earth is about **152 million km** (94.5 million miles) from the Sun.
#
# ...

# %% [markdown]
# # 2. OpenAI API

# %%
from langchain_openai import ChatOpenAI

# Load Model

model  = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0.7,
    max_completion_tokens=10,
    openai_api_key="sk-"
)

result = model.invoke("What is the capital of France?")
print(result.content)

# %% [markdown]
# # 3. Anthropic Claude

# %%
from langchain_anthropic import ChatAnthropic

# Load Model
model = ChatAnthropic(
    model="claude-2",
    temperature=0.7,
    anthropic_api_key="sk-"
)

# Get Response
result = model.invoke("What is the capital of France?")
print(result.content)
